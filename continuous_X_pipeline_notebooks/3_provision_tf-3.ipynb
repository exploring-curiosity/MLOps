# %% [markdown]
# ## Provision infrastructure with Terraform
#
# Now that everything is set up, we are ready to provision our VM resources with Terraform! We will use Terraform to provision 3 VM instances and associated network resources on the OpenStack cloud.

# %% [markdown]
# ### Preliminaries

# %% [markdown]
# Let’s navigate to the directory with the Terraform configuration for our KVM deployment:

# %%
cd /work/MLOps/continous_X_pipeline/tf/kvm/

# %% [markdown]
# and make sure we’ll be able to run the terraform executable by adding the directory in which it is located to our PATH:

# %%
export PATH=/work/.local/bin:$PATH

# %% [markdown]
# We also need to un-set some OpenStack-related environment variables that are set automatically in the Chameleon Jupyter environment, since these will override some Terraform settings that we *don’t* want to override:

# %%
unset $(set | grep -o "^OS_[A-Za-z0-9_]*")

# %% [markdown]
# ### Understanding our Terraform configuration

# %% [markdown]
# [data.tf](https://github.com/exploring-curiosity/MLOps/blob/main/continous_X_pipeline/tf/kvm/data.tf) :  data sources gets existing infrastructure details from OpenStack about resources *not* managed by Terraform.
#
# [main.tf](https://github.com/exploring-curiosity/MLOps/blob/main/continous_X_pipeline/tf/kvm/main.tf) :
# Here we actually allocate the resources. Except for the block storage, which is previously allocated by the data team member and we have to attach it to node1. We are attaching it to node1 because in our kubernetes cluster, node1 will be the leader node. We are doing this because we want to persist data beyond the lifecycle of our VM instances. This persistent block store will have the storage for MinIO, PostgreSQL, etc.
#
# [variables.tf](https://github.com/exploring-curiosity/MLOps/blob/main/continous_X_pipeline/tf/kvm/variables.tf) : lets us define inputs and reuse the configuration across different environments. The value of variables can be passed in the command line arguments when we run a `terraform` command, or by defining environment variables that start with `TF_VAR`. In this example, there’s a variable `instance_hostname` so that we can re-use this configuration to create a VM with any hostname - the variable is used inside the resource block with `name = "${var.instance_hostname}"`.

# %% [markdown]
# ### Applying our Terraform configuration

# %% [markdown]
# First, we need Terraform to set up our working directory, make sure it has “provider” plugins to interact with our infrastructure provider (it will read in `provider.tf` to check), and set up storage for keeping track of the infrastructure state:

# %%
terraform init
# Out:
# Initializing the backend...
# Initializing provider plugins...
# - Reusing previous version of terraform-provider-openstack/openstack from the dependency lock file
# - Using previously-installed terraform-provider-openstack/openstack v1.51.1
#
# Terraform has been successfully initialized!
#
# You may now begin working with Terraform. Try running "terraform plan" to see
# any changes that are required for your infrastructure. All Terraform commands
# should now work.
#
# If you ever set or change modules or backend configuration for Terraform,
# rerun this command to reinitialize your working directory. If you forget, other
# commands will detect it and remind you to do so if necessary.

# %% [markdown]
# To follow the project naming conventions and adding the key. Not this is the name of the key followed by the entire team members.

# %%
# runs in Chameleon Jupyter environment
export TF_VAR_suffix=project38
export TF_VAR_key=id_rsa_chameleon_project_g38

# %% [markdown]
# We should confirm that our planned configuration is valid:

# %%
terraform validate
# Out:
# Success! The configuration is valid.

# %% [markdown]
# Finally, we will apply those changes. (We need to add an `-auto-approve` argument because ordinarily, Terraform prompts the user to type “yes” to approve the changes it will make.)

# %%
terraform apply -auto-approve
# Out:
# data.openstack_networking_secgroup_v2.allow_4000: Reading...
# data.openstack_networking_secgroup_v2.allow_3001: Reading...
# data.openstack_networking_secgroup_v2.allow_http_80: Reading...
# data.openstack_networking_secgroup_v2.allow_8081: Reading...
# data.openstack_networking_secgroup_v2.allow_5000: Reading...
# data.openstack_networking_secgroup_v2.allow_ssh: Reading...
# data.openstack_networking_secgroup_v2.allow_9090: Reading...
# data.openstack_networking_network_v2.sharednet2: Reading...
# data.openstack_networking_secgroup_v2.allow_9001: Reading...
# data.openstack_networking_subnet_v2.sharednet2_subnet: Reading...
# data.openstack_networking_secgroup_v2.allow_5000: Read complete after 1s [id=e429f71c-711a-49c2-bfbd-223eccf40f9e]
# data.openstack_networking_secgroup_v2.allow_http_80: Read complete after 1s [id=5df2db36-79f9-4b9b-b6c9-1ece762d83fb]
# data.openstack_networking_floatingip_v2.reserved_ip: Reading...
# data.openstack_networking_secgroup_v2.allow_ssh: Read complete after 1s [id=47860acf-9269-4d26-84b1-363824f7e0a2]
# data.openstack_networking_secgroup_v2.allow_8080: Reading...
# data.openstack_networking_secgroup_v2.allow_8000: Reading...
# data.openstack_networking_secgroup_v2.allow_3001: Read complete after 1s [id=0ad34c3e-1830-4477-92c8-14adfa372778]
# data.openstack_networking_secgroup_v2.allow_9001: Read complete after 1s [id=ad2912c0-caa9-49e0-b431-b9b3953b91b3]
# data.openstack_networking_secgroup_v2.allow_4000: Read complete after 1s [id=6c5fae54-c3f2-4d70-a80e-1eadb90324f1]
# data.openstack_networking_secgroup_v2.allow_9090: Read complete after 1s [id=d6736d54-d9a4-431c-a5b5-4d29dbcdee03]
# data.openstack_networking_network_v2.sharednet2: Read complete after 1s [id=4ec616b2-79e1-4813-abca-f2ceb41e0a89]
# data.openstack_networking_subnet_v2.sharednet2_subnet: Read complete after 1s [id=00b8d316-7617-4da4-b6c0-b7dd1dd78cd4]
# data.openstack_networking_secgroup_v2.allow_8080: Read complete after 0s [id=e6eff5db-c96d-4e3d-be49-1ade281f4a7a]
# data.openstack_networking_secgroup_v2.allow_8081: Read complete after 1s [id=9806d71f-f0bd-4c5d-8c48-f32db3094575]
# data.openstack_networking_floatingip_v2.reserved_ip: Read complete after 0s [id=736f616f-4d69-4d42-9047-472fd18a99d9]
# data.openstack_networking_secgroup_v2.allow_8000: Read complete after 0s [id=17a6d962-cc23-4551-ac0b-08b098f451d2]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # openstack_compute_instance_v2.nodes["node1"] will be created
#   + resource "openstack_compute_instance_v2" "nodes" {
#       + access_ip_v4        = (known after apply)
#       + access_ip_v6        = (known after apply)
#       + all_metadata        = (known after apply)
#       + all_tags            = (known after apply)
#       + availability_zone   = (known after apply)
#       + created             = (known after apply)
#       + flavor_id           = (known after apply)
#       + flavor_name         = "m1.medium"
#       + force_delete        = false
#       + id                  = (known after apply)
#       + image_id            = (known after apply)
#       + image_name          = "CC-Ubuntu24.04"
#       + key_pair            = "id_rsa_chameleon_project_g38"
#       + name                = "node1-bird-classification-project38"
#       + power_state         = "active"
#       + region              = (known after apply)
#       + security_groups     = (known after apply)
#       + stop_before_destroy = false
#       + updated             = (known after apply)
#       + user_data           = "39b4ec0ad07362f9563af3e1e5f7d5bd2b1b1c71"
#
#       + network {
#           + access_network = false
#           + fixed_ip_v4    = (known after apply)
#           + fixed_ip_v6    = (known after apply)
#           + floating_ip    = (known after apply)
#           + mac            = (known after apply)
#           + name           = (known after apply)
#           + port           = (known after apply)
#           + uuid           = (known after apply)
#         }
#       + network {
#           + access_network = false
#           + fixed_ip_v4    = (known after apply)
#           + fixed_ip_v6    = (known after apply)
#           + floating_ip    = (known after apply)
#           + mac            = (known after apply)
#           + name           = (known after apply)
#           + port           = (known after apply)
#           + uuid           = (known after apply)
#         }
#     }
#
#   # openstack_compute_instance_v2.nodes["node2"] will be created
#   + resource "openstack_compute_instance_v2" "nodes" {
#       + access_ip_v4        = (known after apply)
#       + access_ip_v6        = (known after apply)
#       + all_metadata        = (known after apply)
#       + all_tags            = (known after apply)
#       + availability_zone   = (known after apply)
#       + created             = (known after apply)
#       + flavor_id           = (known after apply)
#       + flavor_name         = "m1.medium"
#       + force_delete        = false
#       + id                  = (known after apply)
#       + image_id            = (known after apply)
#       + image_name          = "CC-Ubuntu24.04"
#       + key_pair            = "id_rsa_chameleon_project_g38"
#       + name                = "node2-bird-classification-project38"
#       + power_state         = "active"
#       + region              = (known after apply)
#       + security_groups     = (known after apply)
#       + stop_before_destroy = false
#       + updated             = (known after apply)
#       + user_data           = "bd2c13906e7dbcd626f84ab1b6d2767cf724d2fa"
#
#       + network {
#           + access_network = false
#           + fixed_ip_v4    = (known after apply)
#           + fixed_ip_v6    = (known after apply)
#           + floating_ip    = (known after apply)
#           + mac            = (known after apply)
#           + name           = (known after apply)
#           + port           = (known after apply)
#           + uuid           = (known after apply)
#         }
#       + network {
#           + access_network = false
#           + fixed_ip_v4    = (known after apply)
#           + fixed_ip_v6    = (known after apply)
#           + floating_ip    = (known after apply)
#           + mac            = (known after apply)
#           + name           = (known after apply)
#           + port           = (known after apply)
#           + uuid           = (known after apply)
#         }
#     }
#
#   # openstack_compute_instance_v2.nodes["node3"] will be created
#   + resource "openstack_compute_instance_v2" "nodes" {
#       + access_ip_v4        = (known after apply)
#       + access_ip_v6        = (known after apply)
#       + all_metadata        = (known after apply)
#       + all_tags            = (known after apply)
#       + availability_zone   = (known after apply)
#       + created             = (known after apply)
#       + flavor_id           = (known after apply)
#       + flavor_name         = "m1.medium"
#       + force_delete        = false
#       + id                  = (known after apply)
#       + image_id            = (known after apply)
#       + image_name          = "CC-Ubuntu24.04"
#       + key_pair            = "id_rsa_chameleon_project_g38"
#       + name                = "node3-bird-classification-project38"
#       + power_state         = "active"
#       + region              = (known after apply)
#       + security_groups     = (known after apply)
#       + stop_before_destroy = false
#       + updated             = (known after apply)
#       + user_data           = "e9cd416c8bc1e50722ca7636f86573505fbb9018"
#
#       + network {
#           + access_network = false
#           + fixed_ip_v4    = (known after apply)
#           + fixed_ip_v6    = (known after apply)
#           + floating_ip    = (known after apply)
#           + mac            = (known after apply)
#           + name           = (known after apply)
#           + port           = (known after apply)
#           + uuid           = (known after apply)
#         }
#       + network {
#           + access_network = false
#           + fixed_ip_v4    = (known after apply)
#           + fixed_ip_v6    = (known after apply)
#           + floating_ip    = (known after apply)
#           + mac            = (known after apply)
#           + name           = (known after apply)
#           + port           = (known after apply)
#           + uuid           = (known after apply)
#         }
#     }
#
#   # openstack_networking_floatingip_v2.floating_ip will be created
#   + resource "openstack_networking_floatingip_v2" "floating_ip" {
#       + address     = (known after apply)
#       + all_tags    = (known after apply)
#       + description = "BirdClef IP for project38"
#       + dns_domain  = (known after apply)
#       + dns_name    = (known after apply)
#       + fixed_ip    = (known after apply)
#       + id          = (known after apply)
#       + pool        = "public"
#       + port_id     = (known after apply)
#       + region      = (known after apply)
#       + subnet_id   = (known after apply)
#       + tenant_id   = (known after apply)
#     }
#
#   # openstack_networking_network_v2.private_net will be created
#   + resource "openstack_networking_network_v2" "private_net" {
#       + admin_state_up          = (known after apply)
#       + all_tags                = (known after apply)
#       + availability_zone_hints = (known after apply)
#       + dns_domain              = (known after apply)
#       + external                = (known after apply)
#       + id                      = (known after apply)
#       + mtu                     = (known after apply)
#       + name                    = "private-net-bird-classification-project38"
#       + port_security_enabled   = false
#       + qos_policy_id           = (known after apply)
#       + region                  = (known after apply)
#       + shared                  = (known after apply)
#       + tenant_id               = (known after apply)
#       + transparent_vlan        = (known after apply)
#
#       + segments (known after apply)
#     }
#
#   # openstack_networking_port_v2.private_net_ports["node1"] will be created
#   + resource "openstack_networking_port_v2" "private_net_ports" {
#       + admin_state_up         = (known after apply)
#       + all_fixed_ips          = (known after apply)
#       + all_security_group_ids = (known after apply)
#       + all_tags               = (known after apply)
#       + device_id              = (known after apply)
#       + device_owner           = (known after apply)
#       + dns_assignment         = (known after apply)
#       + dns_name               = (known after apply)
#       + id                     = (known after apply)
#       + mac_address            = (known after apply)
#       + name                   = "port-node1-bird-classification-project38"
#       + network_id             = (known after apply)
#       + port_security_enabled  = false
#       + qos_policy_id          = (known after apply)
#       + region                 = (known after apply)
#       + tenant_id              = (known after apply)
#
#       + binding (known after apply)
#
#       + fixed_ip {
#           + ip_address = "192.168.1.11"
#           + subnet_id  = (known after apply)
#         }
#     }
#
#   # openstack_networking_port_v2.private_net_ports["node2"] will be created
#   + resource "openstack_networking_port_v2" "private_net_ports" {
#       + admin_state_up         = (known after apply)
#       + all_fixed_ips          = (known after apply)
#       + all_security_group_ids = (known after apply)
#       + all_tags               = (known after apply)
#       + device_id              = (known after apply)
#       + device_owner           = (known after apply)
#       + dns_assignment         = (known after apply)
#       + dns_name               = (known after apply)
#       + id                     = (known after apply)
#       + mac_address            = (known after apply)
#       + name                   = "port-node2-bird-classification-project38"
#       + network_id             = (known after apply)
#       + port_security_enabled  = false
#       + qos_policy_id          = (known after apply)
#       + region                 = (known after apply)
#       + tenant_id              = (known after apply)
#
#       + binding (known after apply)
#
#       + fixed_ip {
#           + ip_address = "192.168.1.12"
#           + subnet_id  = (known after apply)
#         }
#     }
#
#   # openstack_networking_port_v2.private_net_ports["node3"] will be created
#   + resource "openstack_networking_port_v2" "private_net_ports" {
#       + admin_state_up         = (known after apply)
#       + all_fixed_ips          = (known after apply)
#       + all_security_group_ids = (known after apply)
#       + all_tags               = (known after apply)
#       + device_id              = (known after apply)
#       + device_owner           = (known after apply)
#       + dns_assignment         = (known after apply)
#       + dns_name               = (known after apply)
#       + id                     = (known after apply)
#       + mac_address            = (known after apply)
#       + name                   = "port-node3-bird-classification-project38"
#       + network_id             = (known after apply)
#       + port_security_enabled  = false
#       + qos_policy_id          = (known after apply)
#       + region                 = (known after apply)
#       + tenant_id              = (known after apply)
#
#       + binding (known after apply)
#
#       + fixed_ip {
#           + ip_address = "192.168.1.13"
#           + subnet_id  = (known after apply)
#         }
#     }
#
#   # openstack_networking_port_v2.sharednet2_ports["node1"] will be created
#   + resource "openstack_networking_port_v2" "sharednet2_ports" {
#       + admin_state_up         = (known after apply)
#       + all_fixed_ips          = (known after apply)
#       + all_security_group_ids = (known after apply)
#       + all_tags               = (known after apply)
#       + device_id              = (known after apply)
#       + device_owner           = (known after apply)
#       + dns_assignment         = (known after apply)
#       + dns_name               = (known after apply)
#       + id                     = (known after apply)
#       + mac_address            = (known after apply)
#       + name                   = "sharednet2-node1-bird-classification-project38"
#       + network_id             = "4ec616b2-79e1-4813-abca-f2ceb41e0a89"
#       + port_security_enabled  = (known after apply)
#       + qos_policy_id          = (known after apply)
#       + region                 = (known after apply)
#       + security_group_ids     = [
#           + "0ad34c3e-1830-4477-92c8-14adfa372778",
#           + "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           + "47860acf-9269-4d26-84b1-363824f7e0a2",
#           + "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           + "6c5fae54-c3f2-4d70-a80e-1eadb90324f1",
#           + "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           + "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           + "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           + "e429f71c-711a-49c2-bfbd-223eccf40f9e",
#           + "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ]
#       + tenant_id              = (known after apply)
#
#       + binding (known after apply)
#     }
#
#   # openstack_networking_port_v2.sharednet2_ports["node2"] will be created
#   + resource "openstack_networking_port_v2" "sharednet2_ports" {
#       + admin_state_up         = (known after apply)
#       + all_fixed_ips          = (known after apply)
#       + all_security_group_ids = (known after apply)
#       + all_tags               = (known after apply)
#       + device_id              = (known after apply)
#       + device_owner           = (known after apply)
#       + dns_assignment         = (known after apply)
#       + dns_name               = (known after apply)
#       + id                     = (known after apply)
#       + mac_address            = (known after apply)
#       + name                   = "sharednet2-node2-bird-classification-project38"
#       + network_id             = "4ec616b2-79e1-4813-abca-f2ceb41e0a89"
#       + port_security_enabled  = (known after apply)
#       + qos_policy_id          = (known after apply)
#       + region                 = (known after apply)
#       + security_group_ids     = [
#           + "0ad34c3e-1830-4477-92c8-14adfa372778",
#           + "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           + "47860acf-9269-4d26-84b1-363824f7e0a2",
#           + "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           + "6c5fae54-c3f2-4d70-a80e-1eadb90324f1",
#           + "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           + "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           + "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           + "e429f71c-711a-49c2-bfbd-223eccf40f9e",
#           + "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ]
#       + tenant_id              = (known after apply)
#
#       + binding (known after apply)
#     }
#
#   # openstack_networking_port_v2.sharednet2_ports["node3"] will be created
#   + resource "openstack_networking_port_v2" "sharednet2_ports" {
#       + admin_state_up         = (known after apply)
#       + all_fixed_ips          = (known after apply)
#       + all_security_group_ids = (known after apply)
#       + all_tags               = (known after apply)
#       + device_id              = (known after apply)
#       + device_owner           = (known after apply)
#       + dns_assignment         = (known after apply)
#       + dns_name               = (known after apply)
#       + id                     = (known after apply)
#       + mac_address            = (known after apply)
#       + name                   = "sharednet2-node3-bird-classification-project38"
#       + network_id             = "4ec616b2-79e1-4813-abca-f2ceb41e0a89"
#       + port_security_enabled  = (known after apply)
#       + qos_policy_id          = (known after apply)
#       + region                 = (known after apply)
#       + security_group_ids     = [
#           + "0ad34c3e-1830-4477-92c8-14adfa372778",
#           + "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           + "47860acf-9269-4d26-84b1-363824f7e0a2",
#           + "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           + "6c5fae54-c3f2-4d70-a80e-1eadb90324f1",
#           + "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           + "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           + "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           + "e429f71c-711a-49c2-bfbd-223eccf40f9e",
#           + "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ]
#       + tenant_id              = (known after apply)
#
#       + binding (known after apply)
#     }
#
#   # openstack_networking_subnet_v2.private_subnet will be created
#   + resource "openstack_networking_subnet_v2" "private_subnet" {
#       + all_tags          = (known after apply)
#       + cidr              = "192.168.1.0/24"
#       + enable_dhcp       = true
#       + gateway_ip        = (known after apply)
#       + id                = (known after apply)
#       + ip_version        = 4
#       + ipv6_address_mode = (known after apply)
#       + ipv6_ra_mode      = (known after apply)
#       + name              = "private-subnet-bird-classification-project38"
#       + network_id        = (known after apply)
#       + no_gateway        = true
#       + region            = (known after apply)
#       + service_types     = (known after apply)
#       + tenant_id         = (known after apply)
#
#       + allocation_pool (known after apply)
#
#       + allocation_pools (known after apply)
#     }
#
# Plan: 12 to add, 0 to change, 0 to destroy.
#
# Changes to Outputs:
#   + floating_ip_out = (known after apply)
# openstack_networking_network_v2.private_net: Creating...
# openstack_networking_port_v2.sharednet2_ports["node2"]: Creating...
# openstack_networking_port_v2.sharednet2_ports["node3"]: Creating...
# openstack_networking_port_v2.sharednet2_ports["node1"]: Creating...
# openstack_networking_network_v2.private_net: Creation complete after 6s [id=17da8cf0-3cf7-490b-b936-f427c1665c6a]
# openstack_networking_subnet_v2.private_subnet: Creating...
# openstack_networking_port_v2.sharednet2_ports["node1"]: Creation complete after 7s [id=f5fc05e1-019b-48e3-b125-f00db7cdab66]
# openstack_networking_floatingip_v2.floating_ip: Creating...
# openstack_networking_port_v2.sharednet2_ports["node2"]: Creation complete after 7s [id=747fb947-3e9b-4d96-81ee-0213821aac61]
# openstack_networking_port_v2.sharednet2_ports["node3"]: Creation complete after 8s [id=df95c295-cac5-431f-9ac9-3b733b3ee584]
# openstack_networking_subnet_v2.private_subnet: Creation complete after 6s [id=e2a77a96-ba9e-473e-8dd4-ec9b8c7e1849]
# openstack_networking_port_v2.private_net_ports["node3"]: Creating...
# openstack_networking_port_v2.private_net_ports["node2"]: Creating...
# openstack_networking_port_v2.private_net_ports["node1"]: Creating...
# openstack_networking_floatingip_v2.floating_ip: Creation complete after 7s [id=70bed87d-c3cc-4e5f-b8f9-7fc10c707203]
# openstack_networking_port_v2.private_net_ports["node3"]: Creation complete after 5s [id=fa938c4b-1db9-4967-80a4-74a4a21ece68]
# openstack_networking_port_v2.private_net_ports["node2"]: Creation complete after 5s [id=3c369ede-94df-407f-9982-e71d94084ad2]
# openstack_networking_port_v2.private_net_ports["node1"]: Creation complete after 5s [id=f3dce9c9-b26a-44c9-8442-ad92f1b0aefa]
# openstack_compute_instance_v2.nodes["node1"]: Creating...
# openstack_compute_instance_v2.nodes["node3"]: Creating...
# openstack_compute_instance_v2.nodes["node2"]: Creating...
# openstack_compute_instance_v2.nodes["node2"]: Still creating... [10s elapsed]
# openstack_compute_instance_v2.nodes["node1"]: Still creating... [10s elapsed]
# openstack_compute_instance_v2.nodes["node3"]: Still creating... [10s elapsed]
# openstack_compute_instance_v2.nodes["node1"]: Creation complete after 13s [id=2b4edc73-309e-434a-834b-86223f29112b]
# openstack_compute_instance_v2.nodes["node2"]: Creation complete after 13s [id=f4e9f3ec-1163-4f25-bea0-ddc078f89234]
# openstack_compute_instance_v2.nodes["node3"]: Creation complete after 15s [id=c7948485-d4df-4ae1-a257-c1ccf5e0f0e1]
#
# Apply complete! Resources: 12 added, 0 changed, 0 destroyed.
#
# Outputs:
#
# floating_ip_out = "129.114.27.116"
